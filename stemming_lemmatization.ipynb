# %% [markdown]
# <a href="https://colab.research.google.com/github/DilakshanMadhusanka/NLP__/blob/main/stemming_lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import spacy

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

for word in words:
    print(word, " | ", stemmer.stem(word))
# Out:
# eating  |  eat
# eats  |  eat
# eat  |  eat
# ate  |  ate
# adjustable  |  adjust
# rafting  |  raft
# ability  |  abil
# meeting  |  meet

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("eating eats eat ate adjustable rafting ability meeting")

for token in doc:
    print(token, " | ", token.lemma_, " | ", token.lemma)
# Out:
# eating  |  eat  |  9837207709914848172
# eats  |  eat  |  9837207709914848172
# eat  |  eat  |  9837207709914848172
# ate  |  eat  |  9837207709914848172
# adjustable  |  adjustable  |  6033511944150694480
# rafting  |  raft  |  7154368781129989833
# ability  |  ability  |  11565809527369121409
# meeting  |  meeting  |  14798207169164081740

# %%
doc = nlp("Mando talked for 3 hours although talking isn't his thing he became talkative")

for token in doc:
    print(token, " | ", token.lemma_, " | ", token.lemma)
# Out:
# Mando  |  Mando  |  7837215228004622142
# talked  |  talk  |  13939146775466599234
# for  |  for  |  16037325823156266367
# 3  |  3  |  602994839685422785
# hours  |  hour  |  9748623380567160636
# although  |  although  |  343236316598008647
# talking  |  talk  |  13939146775466599234
# is  |  be  |  10382539506755952630
# n't  |  not  |  447765159362469301
# his  |  his  |  2661093235354845946
# thing  |  thing  |  2473243759842082748
# he  |  he  |  1655312771067108281
# became  |  become  |  12558846041070486771
# talkative  |  talkative  |  13364764166055324990

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ar = nlp.get_pipe('attribute_ruler')

ar.add([[{"TEXT":"Bro"}], [{"TEXT":"Brah"}]], {"LEMMA": "Brother"})

doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")

for token in doc:
    print(token.text, " | ", token.lemma_)
# Out:
# Bro  |  Brother
# ,  |  ,
# you  |  you
# wanna  |  wanna
# go  |  go
# ?  |  ?
# Brah  |  Brother
# ,  |  ,
# do  |  do
# n't  |  not
# say  |  say
# no  |  no
# !  |  !
# I  |  I
# am  |  be
# exhausted  |  exhaust

# %%
doc[0]
# Out:
# Bro

# %%
doc[0].lemma_
# Out:
# 'Brother'
