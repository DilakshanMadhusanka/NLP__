# %%
import re

# %%
chat1 = 'codebasics: you ask lot of questions 😒 1235678912, abc@xyz.com'

chat2 = 'codebasics: here it is: (123)-567-8912, abc_82@xyz23.com'

chat3 = 'codebasics: yes, phone: 1235678912 email: abc_A23@xyzAB.com'

# %%
pattern1 = '\d{10}'
matches = re.findall(pattern1, chat1)
matches
# Out:
# ['1235678912']

# %%
pattern1 = '\d{10}'
matches = re.findall(pattern1, chat2)
matches
# Out:
# []

# %%
pattern1 = '\d{10}'
matches = re.findall(pattern1, chat3)
matches
# Out:
# ['1235678912']

# %%
pattern2 = '\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern2, chat1)
matches
# Out:
# []

# %%
pattern2 = '\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern2, chat2)
matches
# Out:
# ['(123)-567-8912']

# %%
pattern2 = '\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern2, chat3)
matches
# Out:
# []

# %%
pattern3 = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern3, chat1)
matches
# Out:
# ['1235678912']

# %%
pattern3 = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern3, chat2)
matches
# Out:
# ['(123)-567-8912']

# %%
pattern3 = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'
matches = re.findall(pattern3, chat3)
matches
# Out:
# ['1235678912']

# %%
pattern4 = '[a-zA-Z0-9_]*@[a-zA-Z0-9]*\.[a-z]*'
matches = re.findall(pattern4, chat1)
matches
# Out:
# ['abc@xyz.com']

# %%
pattern4 = '[a-zA-Z0-9_]*@[a-zA-Z0-9]*\.[a-z]*'
matches = re.findall(pattern4, chat2)
matches
# Out:
# ['abc_82@xyz23.com']

# %%
pattern4 = '[a-zA-Z0-9_]*@[a-zA-Z0-9]*\.[a-z]*'
matches = re.findall(pattern4, chat3)
matches
# Out:
# ['abc_A23@xyzAB.com']

# %%
chat4='codebasics: Hello, I am having an issue with my order # 412889912'
chat5='codebasics: I have a problem with my order number 412889912'
chat6='codebasics: My order 412889912 is having an issue, I was charged 300$ when online it says 280$'

# %%
pattern5 = 'order[^\d]*(\d*)'
matches = re.findall(pattern5, chat4)
matches
# Out:
# ['412889912']

# %%
pattern5 = 'order[^\d]*(\d*)'
matches = re.findall(pattern5, chat5)
matches
# Out:
# ['412889912']

# %%
pattern5 = 'order[^\d]*(\d*)'
matches = re.findall(pattern5, chat6)
matches
# Out:
# ['412889912']

# %%
text = '''
Born Elon Reeve Musk
June 28, 1971 (age 54)
Pretoria, South Africa
Citizenship	
South Africa
Canada
United States
Political party	Independent
Spouses	
Justine Wilson
​
​(m. 2000; div. 2008)​
Talulah Riley
​
​(m. 2010; div. 2016)​
Children	at least 14 (including Vivian Wilson)
Parents	
Errol Musk (father)
Maye Musk (mother)
'''

# %%
pattern6 = 'age (\d+)'
matches = re.findall(pattern6, text)
matches
# Out:
# ['54']

# %%
pattern7 = 'Born(.*)'
matches = re.findall(pattern7, text)
matches[0].strip()
# Out:
# 'Elon Reeve Musk'

# %%
pattern8 = 'Born.*\n(.*)\(age'
matches = re.findall(pattern8, text)
matches[0].strip()
# Out:
# 'June 28, 1971'

# %%
pattern9 = '\(age.*\n(.*)'
matches = re.findall(pattern9, text)
matches[0].strip()
# Out:
# 'Pretoria, South Africa'

# %%
def get_pattern_match(pattern,text):
    matches = re.findall(pattern,text)
    if matches:
        return matches[0]

# %%
get_pattern_match('\(age.*\n(.*)',text)
# Out:
# 'Pretoria, South Africa'

# %%
def get_personal_information(text):
    age = get_pattern_match('age (\d+)',text)
    full_name = get_pattern_match('Born(.*)',text)
    birth_date = get_pattern_match('Born.*\n(.*)\(age',text)
    birth_place = get_pattern_match('\(age.*\n(.*)',text)

    return {
        'age': int(age),
        'name': full_name.strip(),
        'birth_date': birth_date.strip(),
        'birth_place': birth_place.strip()
    }

# %%
get_personal_information(text)
# Out:
# {'age': 54,
#  'name': 'Elon Reeve Musk',
#  'birth_date': 'June 28, 1971',
#  'birth_place': 'Pretoria, South Africa'}
